# %%
import os
import glob
import pandas as pd

# %%
path_list = glob.glob('*.csv')

# %%
AREA = pd.read_csv(path_list[0]).iloc[:,:4].dropna()

# %%
AREA
# Out:
#     CATEGORY     NO AREA_CD       AREA_NM
# 0       관광특구    1.0  POI001  강남 MICE 관광특구
# 1       관광특구    2.0  POI002      동대문 관광특구
# 2       관광특구    3.0  POI003       명동 관광특구
# 3       관광특구    4.0  POI004      이태원 관광특구
# 4       관광특구    5.0  POI005       잠실 관광특구
# ..       ...    ...     ...           ...
# 108       공원  109.0  POI109       잠실종합운동장
# 109       공원  110.0  POI110        잠실한강공원
# 110       공원  111.0  POI111        잠원한강공원
# 111       공원  112.0  POI112           청계산
# 112       공원  113.0  POI113           청와대
#
# [113 rows x 4 columns]

# %%
meta_festival = pd.read_csv(path_list[-1]).iloc[25:48,1:-1].reset_index(drop=True)

# %%
meta_festival.columns = meta_festival.iloc[0]

# %%
meta_festival.drop(0, inplace=True)

# %%
meta_festival.set_index('출력명', inplace=True)

# %%
meta_dict = meta_festival.to_dict()['출력설명']

# %%
meta_festival.to_csv('meta_festival.csv')

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'http://openapi.seoul.go.kr:8088/52775445616b737939387643596a70/xml/citydata_ppltn/1/10/%EA%B4%91%ED%99%94%EB%AC%B8%C2%B7%EB%8D%95%EC%88%98%EA%B6%81'

# %%
req = requests.get(url)

# %%
html = req.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.find_all('area_nm')
# Out:
# [<area_nm>광화문·덕수궁</area_nm>]

# %%
soup.find_all('area_congest_msg')
# Out:
# [<area_congest_msg>사람이 몰려있을 가능성이 낮고 붐빔은 거의 느껴지지 않아요. 도보 이동이 자유로워요.</area_congest_msg>]

# %% [markdown]
# ## festival

# %%
KEY = '69466e4e676b737936366f6e627970'

# %%
# fest_url = f'http://openapi.seoul.go.kr:8088/{KEY}/xml/culturalEventInfo/1/20'
fest_url = f'http://openapi.seoul.go.kr:8088/{KEY}/json/culturalEventInfo/1/20/축제-기타'

# %%
req = requests.get(fest_url)

# %%
json_data = req.json()

# %%
feat_df = pd.DataFrame(json_data.get('culturalEventInfo')['row'])

# %%
feat_df.to_csv('fest_df.csv', index=False)

# %%
feat_df = pd.read_csv('fest_df.csv')

# %%
feat_df.columns
# Out:
# Index(['CODENAME', 'GUNAME', 'TITLE', 'DATE', 'PLACE', 'ORG_NAME', 'USE_TRGT',
#        'USE_FEE', 'PLAYER', 'PROGRAM', 'ETC_DESC', 'ORG_LINK', 'MAIN_IMG',
#        'RGSTDATE', 'TICKET', 'STRTDATE', 'END_DATE', 'THEMECODE', 'LOT', 'LAT',
#        'IS_FREE', 'HMPG_ADDR'],
#       dtype='object')

# %%
feat_df
# Out:
#    CODENAME GUNAME                                              TITLE  \
# 0     축제-기타    마포구          [M클래식 축제] 마포공연예술관광페스티벌 [타케자와 유토 피아노 리사이틀]
# 1     축제-기타    마포구             [M클래식 축제] 마포공연예술관광페스티벌 킷 암스트롱 피아노 리사이틀
# 2     축제-기타    은평구                       2023 서울기록페어: 기록이 모이면 서울이 됩니다
# 3     축제-기타    마포구        [M클래식 축제] 마포공연예술관광페스티벌 피아니스트 송영민의 [수아레 콘서트]
# 4     축제-기타    강북구                                        강북마임축제 [꿈짓]
# 5     축제-기타    종로구                           [돈의문박물관마을] 돈의Moon나이트 10월
# 6     축제-기타    양천구                               제27회 목동로데오 패션거리 문화축제
# 7     축제-기타    송파구                               송파 예술단지 프로젝트 [아트나바다]
# 8     축제-기타    성동구       2023 한강페스티벌 가을 [Hangang River Festival-Fall]
# 9     축제-기타    강서구                                   [강서구청] 제21회 허준축제
# 10    축제-기타    마포구                                 2023 홍대 청년 일자리 페스타
# 11    축제-기타    동작구          동작문화재단 제5회 문화정책포럼 개최 [지역 문화자원 활용과 로컬 브랜딩]
# 12    축제-기타     중구                     빛남만남 플리마켓 - 2023 남대문시장 악세서리데이
# 13    축제-기타    마포구       [M클래식 축제] 마포공연예술관광페스티벌 지휘자 서희태의 [프랑스 오페라 갈라]
# 14    축제-기타    마포구                                2023 서울 반려동물 한마당 축제
# 15    축제-기타    종로구                             [돈의문박물관마을] 돈의문골목시장 10월
# 16    축제-기타    마포구  [M클래식 축제] 마포공연예술관광페스티벌 카운터 테너 정민호 [Baroque sea...
# 17    축제-기타     중구                                     서울 핀테크 위크 2023
# 18    축제-기타    마포구          [M클래식 축제] 첼리스트 양성원 & 피아니스트 유성호 첫 듀오 리사이틀
# 19    축제-기타    송파구                                      제23회 한성백제 문화제
#
#                      DATE                           PLACE   ORG_NAME  \
# 0   2023-12-07~2023-12-07                    마포아트센터 아트홀 맥     마포문화재단
# 1   2023-12-06~2023-12-06                     마포아트센터 아트홀맥     마포문화재단
# 2   2023-10-24~2023-10-29       서울기록원(서울특별시 은평구 통일로62길 7)       서울시청
# 3   2023-10-18~2023-10-18                    마포아트센터 아트홀 맥     마포문화재단
# 4   2023-10-15~2023-10-15         북서울꿈의숲(문화광장, 볼프라자, 창포원)     강북문화재단
# 5   2023-10-14~2023-10-28                     돈의문박물관마을 곳곳   돈의문박물관마을
# 6   2023-10-14~2023-10-14     목동로데오거리(목동역 2번출구-목동로25길 일대)       양천구청
# 7   2023-10-14~2023-10-14            송파근린공원 (송파대로 42길29)      송파문화재단
# 8   2023-10-13~2023-10-22                         한강공원 일대     한강사업본부
# 9   2023-10-13~2023-10-15                      서울식물원 잔디마당       강서구청
# 10  2023-10-13~2023-10-13          레드로드R4(축제거리), (상상마당인근)       마포구청
# 11  2023-10-12~2023-10-12                 까망돌도서관 지하1충 공연장     동작문화재단
# 12  2023-10-11~2023-10-13  회현역 5번출구부터 남대문시장 대도상가 E동 사거리까지         기타
# 13  2023-10-10~2023-10-10                    마포아트센터 아트홀 맥     마포문화재단
# 14  2023-10-08~2023-10-08               월드컵공원 평화의광장, 하늘공원       서울시청
# 15  2023-10-07~2023-10-28                     돈의문박물관마을 곳곳   돈의문박물관마을
# 16  2023-10-05~2023-10-05                     마포아트센터 아트홀맥     마포문화재단
# 17  2023-10-04~2023-10-06                      DDP 아트홀 2관  동대문디자인플라자
# 18  2023-09-26~2023-09-26                     마포아트센터 아트홀맥     마포문화재단
# 19  2023-09-22~2023-09-24                  서울 올림픽공원 평화의 문       송파구청
#
#           USE_TRGT                              USE_FEE  \
# 0            8세 이상  R석 50,000원 / S석 30,000 / A석 20,000원
# 1            8세 이상  R석 50,000원 / S석 30,000 / A석 20,000원
# 2         프로그램별 상이                                  NaN
# 3            8세 이상                           전석 20,000원
# 4              누구나                                  NaN
# 5           시민 누구나                                   무료
# 6              누구나                                  NaN
# 7              누구나                                  NaN
# 8              누구나                       무료(일부 프로그램 유료)
# 9              누구나                                   무료
# 10             누구나                                  NaN
# 11  문화예술에 관심있는 누구나                                  NaN
# 12             누구나                                   무료
# 13           8세 이상                          전석 20,000원
# 14             누구나                                  NaN
# 15          시민 누구나                                   무료
# 16           8세 이상                           전석 20,000원
# 17         홈페이지 참고                                  NaN
# 18           8세 이상  R석 50,000원 / S석 30,000 / A석 20,000원
# 19             누구나                                  NaN
#
#                                                PLAYER  \
# 0                                            타케자와 유토
# 1                                              킷 암스트롱
# 2                                                 NaN
# 3                                  송연민, 고상지, 박건우, 안동영
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   * 10/14(토): 다비치, 김태우, 김다현  * 10/15(일): 코요테, 경서...
# 10  팝페라 가수 아리현/ 지휘자 조만근/ 뮤지컬배우 이슬기/ 버스커 헤디/ 버스커 우지...
# 11                                                NaN
# 12                                                NaN
# 13     서희태, 김유미,변지영, 정주연, 문세훈, 김성결, 전태현, 뉴서울필하모닉오케스트라
# 14                                                NaN
# 15                                                NaN
# 16                                   정민호, 카메라타 인티콰 서울
# 17                                                NaN
# 18                                          양성원, 유성호
# 19                 오마이걸, 백지영, 알리, 홀리뱅, 머스트비, 홍지윤, 민우혁
#
#                                               PROGRAM  ...  \
# 0                                                 NaN  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5   돈의문박물관마을에서 한밤 중 취향을 발견하는 특별한 경험! 공연, 전시, 체험, 투...  ...
# 6                                                 NaN  ...
# 7   <아트나바다: 아트와 나, 부산물의 바다> 는   송파를 기반으로 활동하는 예술인 ...  ...
# 8                                                 NaN  ...
# 9   허준전국가요제, 허준콘서트, 허주니어 선발대회 등 특색 있는 프로그램 및 의료건강체...  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12  일반 소비자가 구매하기 어려웠던 '남대문 도매시장의 패션악세서리'를 만나볼 수 있는...  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15  돈의문박물관마을의 골목 구석구석에서 즐기는 도시여행자와 온 가족을 위한 살거리, 즐...  ...
# 16                                                NaN  ...
# 17                                                NaN  ...
# 18                                                NaN  ...
# 19                 개막식, 한마음어울마당, 송파구민의 날, 한성문화콘서트,폐막식  ...
#
#                                              MAIN_IMG    RGSTDATE TICKET  \
# 0   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 1   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 2   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-10-10     기관
# 3   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 4   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-27     기관
# 5   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-23     기관
# 6   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-15     기관
# 7   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-10-06     기관
# 8   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-11     기관
# 9   https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-13     기관
# 10  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-10-08     기관
# 11  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-21     기관
# 12  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-10-04     시민
# 13  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 14  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-18     기관
# 15  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-23     기관
# 16  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 17  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-09-11     기관
# 18  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-07-06     기관
# 19  https://culture.seoul.go.kr/cmmn/file/getImage...  2023-08-28     기관
#
#                  STRTDATE               END_DATE THEMECODE        LOT  \
# 0   2023-12-07 00:00:00.0  2023-12-07 00:00:00.0        기타  37.549906
# 1   2023-12-06 00:00:00.0  2023-12-06 00:00:00.0        기타  37.549906
# 2   2023-10-24 00:00:00.0  2023-10-29 00:00:00.0        기타  37.607533
# 3   2023-10-18 00:00:00.0  2023-10-18 00:00:00.0        기타  37.549906
# 4   2023-10-15 00:00:00.0  2023-10-15 00:00:00.0        기타  37.620254
# 5   2023-10-14 00:00:00.0  2023-10-28 00:00:00.0        기타  37.568824
# 6   2023-10-14 00:00:00.0  2023-10-14 00:00:00.0       NaN  37.517048
# 7   2023-10-14 00:00:00.0  2023-10-14 00:00:00.0        기타  37.505929
# 8   2023-10-13 00:00:00.0  2023-10-22 00:00:00.0        기타  37.538956
# 9   2023-10-13 00:00:00.0  2023-10-15 00:00:00.0        기타  37.569657
# 10  2023-10-13 00:00:00.0  2023-10-13 00:00:00.0       NaN  37.551226
# 11  2023-10-12 00:00:00.0  2023-10-12 00:00:00.0        기타  37.505120
# 12  2023-10-11 00:00:00.0  2023-10-13 00:00:00.0        기타  37.558055
# 13  2023-10-10 00:00:00.0  2023-10-10 00:00:00.0        기타  37.549906
# 14  2023-10-08 00:00:00.0  2023-10-08 00:00:00.0        기타  37.568475
# 15  2023-10-07 00:00:00.0  2023-10-28 00:00:00.0        기타  37.568824
# 16  2023-10-05 00:00:00.0  2023-10-05 00:00:00.0        기타  37.549906
# 17  2023-10-04 00:00:00.0  2023-10-06 00:00:00.0       NaN  37.566813
# 18  2023-09-26 00:00:00.0  2023-09-26 00:00:00.0        기타  37.549906
# 19  2023-09-22 00:00:00.0  2023-09-24 00:00:00.0        기타  37.520534
#
#            LAT  IS_FREE                                          HMPG_ADDR
# 0   126.945534       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 1   126.945534       유료  https://culture.seoul.go.kr/culture/culture/cu...
# 2   126.934860       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 3   126.945534       유료  https://culture.seoul.go.kr/culture/culture/cu...
# 4   127.044325       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 5   126.968523       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 6   126.866477       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 7   127.109731       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 8   127.041669       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 9   126.835007       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 10  126.921338       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 11  126.960611       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 12  126.977249       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 13  126.945534       유료  https://culture.seoul.go.kr/culture/culture/cu...
# 14  126.886830       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 15  126.968523       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 16  126.945534       유료  https://culture.seoul.go.kr/culture/culture/cu...
# 17  127.009626       무료  https://culture.seoul.go.kr/culture/culture/cu...
# 18  126.945534       유료  https://culture.seoul.go.kr/culture/culture/cu...
# 19  127.120813       무료  https://culture.seoul.go.kr/culture/culture/cu...
#
# [20 rows x 22 columns]

# %%
feat_df[['CODENAME','LOT','LAT']]
# Out:
#    CODENAME        LOT         LAT
# 0     축제-기타  37.549906  126.945534
# 1     축제-기타  37.549906  126.945534
# 2     축제-기타  37.607533  126.934860
# 3     축제-기타  37.549906  126.945534
# 4     축제-기타  37.620254  127.044325
# 5     축제-기타  37.568824  126.968523
# 6     축제-기타  37.517048  126.866477
# 7     축제-기타  37.505929  127.109731
# 8     축제-기타  37.538956  127.041669
# 9     축제-기타  37.569657  126.835007
# 10    축제-기타  37.551226  126.921338
# 11    축제-기타  37.505120  126.960611
# 12    축제-기타  37.558055  126.977249
# 13    축제-기타  37.549906  126.945534
# 14    축제-기타  37.568475  126.886830
# 15    축제-기타  37.568824  126.968523
# 16    축제-기타  37.549906  126.945534
# 17    축제-기타  37.566813  127.009626
# 18    축제-기타  37.549906  126.945534
# 19    축제-기타  37.520534  127.120813

# %%
feat_df.LOT, feat_df.LAT
# Out:
# (0     37.549906
#  1     37.549906
#  2     37.607533
#  3     37.549906
#  4     37.620254
#  5     37.568824
#  6     37.517048
#  7     37.505929
#  8     37.538956
#  9     37.569657
#  10    37.551226
#  11    37.505120
#  12    37.558055
#  13    37.549906
#  14    37.568475
#  15    37.568824
#  16    37.549906
#  17    37.566813
#  18    37.549906
#  19    37.520534
#  Name: LOT, dtype: float64,
#  0     126.945534
#  1     126.945534
#  2     126.934860
#  3     126.945534
#  4     127.044325
#  5     126.968523
#  6     126.866477
#  7     127.109731
#  8     127.041669
#  9     126.835007
#  10    126.921338
#  11    126.960611
#  12    126.977249
#  13    126.945534
#  14    126.886830
#  15    126.968523
#  16    126.945534
#  17    127.009626
#  18    126.945534
#  19    127.120813
#  Name: LAT, dtype: float64)

# %%
meta_festival
# Out:
# 0               출력설명
# 출력명
# CODENAME          분류
# GUNAME           자치구
# TITLE         공연/행사명
# DATE           날짜/시간
# PLACE             장소
# ORG_NAME         기관명
# USE_TRGT        이용대상
# USE_FEE         이용요금
# PLAYER         출연자정보
# PROGRAM       프로그램소개
# ETC_DESC        기타내용
# ORG_LINK     홈페이지 주소
# MAIN_IMG       대표이미지
# RGSTDATE         신청일
# TICKET         시민/기관
# STRTDATE         시작일
# END_DATE         종료일
# THEMECODE       테마분류
# LOT          위도(X좌표)
# LAT          경도(Y좌표)
# IS_FREE          유무료
# HMPG_ADDR  문화포털상세URL
